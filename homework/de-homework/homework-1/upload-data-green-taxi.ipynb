# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.1'

# %%
df = pd.read_csv('green_tripdata_2019-01.csv.gz', nrows=100)

# %%
df
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1          2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2          2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3          2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4          2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-01-01 00:15:42   2019-01-01 00:41:04                  N
# 96         2  2019-01-01 00:21:28   2019-01-01 00:48:15                  N
# 97         2  2019-01-01 00:17:10   2019-01-01 00:23:34                  N
# 98         2  2019-01-01 00:25:01   2019-01-01 00:43:55                  N
# 99         2  2019-01-01 00:36:56   2019-01-01 00:43:50                  N
#
# ...

# %%
# get schema for ddl
pd.io.sql.get_schema(df, 'green_taxi_data')
# Out:
# 'CREATE TABLE "green_taxi_data" (\n"VendorID" INTEGER,\n  "lpep_pickup_datetime" TEXT,\n  "lpep_dropoff_datetime" TEXT,\n  "store_and_fwd_flag" TEXT,\n  "RatecodeID" INTEGER,\n  "PULocationID" INTEGER,\n  "DOLocationID" INTEGER,\n  "passenger_count" INTEGER,\n  "trip_distance" REAL,\n  "fare_amount" REAL,\n  "extra" REAL,\n  "mta_tax" REAL,\n  "tip_amount" REAL,\n  "tolls_amount" REAL,\n  "ehail_fee" REAL,\n  "improvement_surcharge" REAL,\n  "total_amount" REAL,\n  "payment_type" INTEGER,\n  "trip_type" INTEGER,\n  "congestion_surcharge" REAL\n)'

# %%
# remove line breaks - use print function
print(pd.io.sql.get_schema(df, 'green_taxi_data'))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TEXT,
#   "lpep_dropoff_datetime" TEXT,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
pd.to_datetime(df.lpep_pickup_datetime)
# Out:
# 0    2018-12-21 15:17:29
# 1    2019-01-01 00:10:16
# 2    2019-01-01 00:27:11
# 3    2019-01-01 00:46:20
# 4    2019-01-01 00:19:06
#              ...
# 95   2019-01-01 00:15:42
# 96   2019-01-01 00:21:28
# 97   2019-01-01 00:17:10
# 98   2019-01-01 00:25:01
# 99   2019-01-01 00:36:56
# Name: lpep_pickup_datetime, Length: 100, dtype: datetime64[ns]

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df, 'green_taxi_data'))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TIMESTAMP,
#   "lpep_dropoff_datetime" TIMESTAMP,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
! pip install sqlalchemy psycopg2-binary -Uq

# %%
#  connection to postgres
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
print(pd.io.sql.get_schema(df, 'green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	lpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
# batch data ingestion to postgres using iterator
df_iter = pd.read_csv('green_tripdata_2019-01.csv.gz', iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1             2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2             2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3             2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4             2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-01-06 09:56:09   2019-01-06 10:01:30                  N
# 99996         2  2019-01-06 09:12:49   2019-01-06 09:52:38                  N
# 99997         2  2019-01-06 09:02:06   2019-01-06 09:37:42                  N
# 99998         2  2019-01-06 09:55:01   2019-01-06 10:04:34                  N
# 99999         2  2019-01-06 09:59:04   2019-01-06 10:24:33                  N
#
# ...

# %%
len(df)
# Out:
# 100000

# %%
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
# table headers to postgres
df.head(0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# 1st chunk of data to postgres
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 4.55 s, sys: 234 ms, total: 4.78 s
# Wall time: 9.97 s
# 1000

# %%
from time import time

# %%
# chunks of data to postgres

while True:
    t_start = time()
    
    df = next(df_iter)
    
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
     
    df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
    
    t_end = time()
    
    print('inserted another chunk..., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk..., took 9.992 second
# inserted another chunk..., took 10.068 second
# inserted another chunk..., took 9.890 second
# inserted another chunk..., took 9.746 second
# inserted another chunk..., took 10.031 second
# inserted another chunk..., took 3.199 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[25], line 6
#       3 while True:
#       4     t_start = time()
# ----> 6     df = next(df_iter)
#       8     df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
#       9     df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
#
# File ~/anaconda3/envs/deep-learning-1/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1698, in TextFileReader.__next__(self)
#    1696 def __next__(self) -> DataFrame:
#    1697     try:
# -> 1698         return self.get_chunk()
#    1699     except StopIteration:
# ...

# %% [markdown]
# ## Upload zone file to postgres

# %%
df_zones = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone

# %%
df_zones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 265 entries, 0 to 264
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   LocationID    265 non-null    int64
#  1   Borough       265 non-null    object
#  2   Zone          264 non-null    object
#  3   service_zone  263 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.4+ KB

# %%
df_zones.to_sql(name='zones', con=engine, if_exists='replace')
# Out:
# 265
