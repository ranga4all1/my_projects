# %% [markdown]
# # Recommendations

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# copy files to runtime
# !cp /content/drive/MyDrive/Colab_Notebooks/Projects/books_recommendation/datasets/goodreads_interactions.csv .
# !cp /content/drive/MyDrive/Colab_Notebooks/Projects/books_recommendation/datasets/book_id_map.csv .
# !cp /content/drive/MyDrive/Colab_Notebooks/Projects/books_recommendation/books_titles.json .

# %%
# list of liked books created by using search engine built earlier
liked_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %%
liked_books
# Out:
# ['4408', '31147619', '29983711', '9401317', '9317691', '8153988', '20494944']

# %%
# let's looks at book_id_map.csv
# !head book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
# Book_id column in 2 dataset files are different - let's map those using book_id_map.csv

csv_book_mapping = {}

with open("book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
csv_book_mapping['0']
# Out:
# '34684622'

# %%
# number of book mappings
len(csv_book_mapping)
# Out:
# 2360651

# %%
# !wc -l goodreads_interactions.csv
# Out:
# 228648343 goodreads_interactions.csv

# %%
# !ls -lh goodreads_interactions.csv
# Out:
# -rw------- 1 root root 4.1G Feb 24 00:13 goodreads_interactions.csv

# %%
# !head goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %% [markdown]
# ### finding users who like same books as us

# %%
#  use streaming method to load data

overlap_users = set()

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            continue

        try:
            rating = int(rating)
        except ValueError:
            continue
        
        book_id = csv_book_mapping[csv_id]
        
        if book_id in liked_books and rating >= 4:
                overlap_users.add(user_id)

# %%
len(overlap_users)
# Out:
# 2029

# %%
# find what books those users liked

rec_lines = []

with open("goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",")
        
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append([user_id, book_id, rating])

# %%
len(rec_lines)
# Out:
# 1530257

# %%
# convert to dataframe

import pandas as pd

recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs["book_id"] = recs["book_id"].astype(str)

# %%
recs
# Out:
#         user_id   book_id rating
# 0           284    977284      3
# 1           284    890054      4
# 2           284    837153      3
# 3           284   1586480      4
# 4           284     41814      5
# ...         ...       ...    ...
# 1530252  873216    127455      0
# 1530253  873216  10365343      0
# 1530254  873216  16131077      0
# 1530255  873216  18781576      0
# 1530256  873216     43615      0
#
# [1530257 rows x 3 columns]

# %%
top_recs = recs["book_id"].value_counts().head(10)

# %%
top_recs = top_recs.index.values

# %%
books_titles = pd.read_json("books_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
books_titles.head()
# Out:
#    book_id  ...                                         mod_title
# 0  7327624  ...    the unschooled wizard sun wolf and starhawk 12
# 1  6066819  ...                              best friends forever
# 2   287141  ...                     the aeneid for boys and girls
# 3  6066812  ...  alls fairy in love and war avalon web of magic 8
# 4   287149  ...                               the devils notebook
#
# [5 rows x 6 columns]

# %% [markdown]
# ### creating initial books recommendations

# %%
books_titles[books_titles["book_id"].isin(top_recs)]
# Out:
#           book_id  ...                                          mod_title
# 53027       77203  ...                                    the kite runner
# 284473    2767052  ...                the hunger games the hunger games 1
# 401395       5107  ...                             the catcher in the rye
# 463463       4671  ...                                   the great gatsby
# 615314       5470  ...                                               1984
# 757376      38447  ...                                 the handmaids tale
# 790927       2657  ...                              to kill a mockingbird
# 878151   18143977  ...                        all the light we cannot see
# 878545          3  ...  harry potter and the sorcerers stone harry pot...
# 1062354  29983711  ...                                           pachinko
#
# [10 rows x 6 columns]

# %%
top_recs
# Out:
# array(['2767052', '29983711', '2657', '3', '4671', '18143977', '38447',
#        '5470', '77203', '5107'], dtype=object)

# %% [markdown]
# ### improving our book recommendations

# %%
all_recs = recs["book_id"].value_counts()

# %%
all_recs
# Out:
# 2767052     1092
# 29983711    1089
# 2657        1074
# 3           1048
# 4671        1028
#             ...
# 21843400       1
# 18595019       1
# 22514204       1
# 22733082       1
# 18781576       1
# Name: book_id, Length: 364169, dtype: int64

# %%
all_recs = all_recs.to_frame().reset_index()
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs
# Out:
#          book_id  book_count
# 0        2767052        1092
# 1       29983711        1089
# 2           2657        1074
# 3              3        1048
# 4           4671        1028
# ...          ...         ...
# 364164  21843400           1
# 364165  18595019           1
# 364166  22514204           1
# 364167  22733082           1
# 364168  18781576           1
#
# [364169 rows x 2 columns]

# %%
all_recs.head(5)
# Out:
#     book_id  book_count
# 0   2767052        1092
# 1  29983711        1089
# 2      2657        1074
# 3         3        1048
# 4      4671        1028

# %%
# merge

all_recs = all_recs.merge(books_titles, how="inner", on="book_id")

# %%
all_recs
# Out:
#          book_id  ...                                          mod_title
# 0        2767052  ...                the hunger games the hunger games 1
# 1       29983711  ...                                           pachinko
# 2           2657  ...                              to kill a mockingbird
# 3              3  ...  harry potter and the sorcerers stone harry pot...
# 4           4671  ...                                   the great gatsby
# ...          ...  ...                                                ...
# 328338  22707746  ...                            names can never hurt me
# 328339  21843400  ...  blackbird knitting in a bunnys lair granby kni...
# 328340  18595019  ...                                           bar none
# 328341  22514204  ...                      unexpected trust unexpected 2
# 328342  18781576  ...                            wolverine old man logan
#
# [328343 rows x 7 columns]

# %%
# create score
all_recs["score"] = all_recs["book_count"] * (all_recs["book_count"] / all_recs["ratings"])

# %%
all_recs.sort_values("score", ascending=False).head(10)
# Out:
#        book_id  ...       score
# 1     29983711  ...  145.315648
# 238       4408  ...   31.020888
# 724    9317691  ...   29.362416
# 236   32920226  ...   23.428571
# 216   30753987  ...   20.878972
# 7617  26856502  ...   20.828571
# 1287  31147619  ...   19.977044
# 5517  34927828  ...   19.557143
# 249    8153988  ...   18.063415
# 6011  35099035  ...   17.253731
#
# [10 rows x 8 columns]

# %%
all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False).head(10)
# Out:
#       book_id  book_count  ...                             mod_title       score
# 1    29983711        1089  ...                              pachinko  145.315648
# 238      4408         327  ...                          east of eden   31.020888
# 236  32920226         328  ...                    sing unburied sing   23.428571
# 216  30753987         342  ...                           the leavers   20.878972
# 249   8153988         322  ...  the eye of the world wheel of time 1   18.063415
# 441  33253215         236  ...           the hearts invisible furies   15.347479
# 71   30688435         533  ...                             exit west   13.288848
# 251  32283423         321  ...                          american war   13.251157
# 228  26025588         335  ...                   behold the dreamers   12.762993
# 345  17912498         266  ...                the queen of the night   11.570891
#
# [10 rows x 8 columns]

# %%
popular_recs = all_recs[all_recs["book_count"] > 200].sort_values("score", ascending=False)

# %%
# create functions

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)


popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_cbaf1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >book_id</th>
#       <th class="col_heading level0 col1" >book_count</th>
#       <th class="col_heading level0 col2" >title</th>
#       <th class="col_heading level0 col3" >ratings</th>
#       <th class="col_heading level0 col4" >url</th>
#       <th class="col_heading level0 col5" >image_url</th>
#       <th class="col_heading level0 col6" >mod_title</th>
#       <th class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbaf1_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_cbaf1_row0_col0" class="data row0 col0" >32920226</td>
#       <td id="T_cbaf1_row0_col1" class="data row0 col1" >328</td>
#       <td id="T_cbaf1_row0_col2" class="data row0 col2" >Sing, Unburied, Sing</td>
#       <td id="T_cbaf1_row0_col3" class="data row0 col3" >4592</td>
#       <td id="T_cbaf1_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32920226-sing-unburied-sing">Goodreads</a></td>
#       <td id="T_cbaf1_row0_col5" class="data row0 col5" >https://images.gr-assets.com/books/1499340866m/32920226.jpg</td>
#       <td id="T_cbaf1_row0_col6" class="data row0 col6" >sing unburied sing</td>
#       <td id="T_cbaf1_row0_col7" class="data row0 col7" >23.428571</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf1_level0_row1" class="row_heading level0 row1" >216</th>
#       <td id="T_cbaf1_row1_col0" class="data row1 col0" >30753987</td>
#       <td id="T_cbaf1_row1_col1" class="data row1 col1" >342</td>
#       <td id="T_cbaf1_row1_col2" class="data row1 col2" >The Leavers</td>
#       <td id="T_cbaf1_row1_col3" class="data row1 col3" >5602</td>
#       <td id="T_cbaf1_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show
col4" ><a target="_blank" href="https://www.goodreads.com/book/show/26025588-behold-the-dreamers">Goodreads</a></td>
#       <td id="T_cbaf1_row5_col5" class="data row5 col5" >https://images.gr-assets.com/books/1439643293m/26025588.jpg</td>
#       <td id="T_cbaf1_row5_col6" class="data row5 col6" >behold the dreamers</td>
#       <td id="T_cbaf1_row5_col7" class="data row5 col7" >12.762993</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf1_level0_row6" class="row_heading level0 row6" >345</th>
#       <td id="T_cbaf1_row6_col0" class="data row6 col0" >17912498</td>
#       <td id="T_cbaf1_row6_col1" class="data row6 col1" >266</td>
#       <td id="T_cbaf1_row6_col2" class="data row6 col2" >The Queen of the Night</td>
#       <td id="T_cbaf1_row6_col3" class="data row6 col3" >6115</td>
#       <td id="T_cbaf1_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/17912498-the-queen-of-the-night">Goodreads</a></td>
#       <td id="T_cbaf1_row6_col5" class="data row6 col5" >https://images.gr-assets.com/books/1460425080m/17912498.jpg</td>
#       <td id="T_cbaf1_row6_col6" class="data row6 col6" >the queen of the night</td>
#       <td id="T_cbaf1_row6_col7" class="data row6 col7" >11.570891</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf1_level0_row7" class="row_heading level0 row7" >325</th>
#       <td id="T_cbaf1_row7_col0" class="data row7 col0" >28114515</td>
#       <td id="T_cbaf1_row7_col1" class="data row7 col1" >276</td>
#       <td id="T_cbaf1_row7_col2" class="data row7 col2" >The Wangs vs. the World</td>
#       <td id="T_cbaf1_row7_col3" class="data row7 col3" >7044</td>
#       <td id="T_cbaf1_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/28114515-the-wangs-vs-the-world">Goodreads</a></td>
#       <td id="T_cbaf1_row7_col5" class="data row7 col5" >https://images.gr-assets.com/books/1451493647m/28114515.jpg</td>
#       <td id="T_cbaf1_row7_col6" class="data row7 col6" >the wangs vs the world</td>
#       <td id="T_cbaf1_row7_col7" class="data row7 col7" >10.814310</td>
#     </tr>
#     <tr>
#       <th id="T_cbaf1_level0_row8" class="row_heading level0 row8" >108</th>
#       <td id="T_cbaf1_row8_col0" class="data row8 col0" >34273236</td>
#       <td id="T_cbaf1_row8_col1" class="data row8 col1" >459</td>
#       <td id="T_cbaf1_row8_col2" class="data row8 col2" >Little Fires Everywhere</td>
#       <td id="T_cbaf1_row8_col3" class="data row8 col3" >21135</td>
#       <td id="T_cbaf1_row8_col4" class="data row8 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/34273236-little-fires-everywhere">Goodreads</a></td>
#       <td id="T_cbaf1_row8_col5" class="data row8 col5" >https://images.gr-assets.com/books/1490351351m/34273236.jpg</td>
#       <td id="T_cbaf1_row8_col6" class="data row8 col6" >little fires everywhere</td>
#       <td id="T_cbaf1_row8_col7" class="data row8 col7" >9.96

# %% [markdown]
# ### Wrap up and next steps
#
# 1. collaborative filtering -- to improve recommendations
